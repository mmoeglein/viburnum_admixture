# %%
#load packages
#ipyrad_10_2019 environment 
import ipyrad as ip
import ipyrad.analysis as ipa
import pandas as pd
import toyplot

# %%
#load path to the .snps.hdf5 database file for each assembly (parents, parents+hybrids, and just hybrids)
data_p = "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_parent/parent_outfiles/parent.snps.hdf5"
data_ph = "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_parent_hybrid/parent_hybrid_outfiles/parent_hybrid.snps.hdf5"
data_h = "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_hybrid/hybrids_outfiles/hybrids.snps.hdf5"
data_hartout = "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_hartout/hartout_outfiles/hartout.snps.hdf5"
data_denovo_yas = "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_yas/denovo_yas_outfiles/denovo_yas.snps.hdf5"
data_denovo_zin= "/home/mm3465/scratch60/ipyrad/ipyrad_denovo_zin/denovo_zin_outfiles/denovo_zin.snps.hdf5"

# %%
#run a tiny job to see if things are working then scale up
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2-4",
    data=data_p,
    mincov=0.5,
)

struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

#denovo parent assembly k=2-5, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2, 3, 4], auto=True)
#ran in about five minutes at mincov0.5, burnin 50, numreps 100, nreps 3 
#mincov0.5, burnin 500, numreps 1000, nreps 3 (about 20 minutes)
#mincov0.5, burnin 5000, numreps 10000, nreps 3 (start @ 3:15 -> about 6:15)
#delete old output, up parameters, and rewrite files with test runs until replication is sufficient
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 177550
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 178934
# Sites after filtering: 66387
# Sites containing missing values: 66317 (99.89%)
# Missing values in SNP matrix: 455780 (40.39%)
# SNPs (total): 66387
# SNPs (unlinked): 19113
# [                    ]   0% 1:14:50 | running 9 structure jobs

# %%
#plot output from test run above
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#67a9cf", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=4
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 4
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2, 1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#d0d1e6", "#02818a", "#67a9cf"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K4] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#already ran this through structure, so reloading files for plotting
#results from mincov0.5, burnin 5000, numreps 10000, nreps 3 (start @ 3:15 -> about 6:15)
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2-4",
    data=data_p,
    mincov=0.5,
)
# Out:
# 9 previous results loaded for run [test_denovo_parent_k2-4]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 177550
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 178934
# Sites after filtering: 66387
# Sites containing missing values: 66317 (99.89%)
# Missing values in SNP matrix: 455780 (40.39%)
# SNPs (total): 66387
# SNPs (unlinked): 19113

# %%
#plot output from test run above
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#67a9cf", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=4
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 4
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2, 1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#d0d1e6", "#02818a", "#67a9cf"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K4] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#try running more reps of k=2 
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2-4",
    data=data_p,
    mincov=0.5,
)

struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

#denovo parent assembly k=2-5, 3 reps 
#downstream analysis combines reps
struct.run(nreps=10, kpop=[2], auto=True)
# Out:
# 9 previous results loaded for run [test_denovo_parent_k2-4]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 177550
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 178934
# Sites after filtering: 66387
# Sites containing missing values: 66317 (99.89%)
# Missing values in SNP matrix: 455780 (40.39%)
# SNPs (total): 66387
# SNPs (unlinked): 19113
# [                    ]   0% 1:12:30 | running 7 structure jobs

# %%
#the added k=2 replicates from the above cell ran in just under 2 hours
#reload structure runs and plot new k=2 clumpp to check more replicates
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2-4",
    data=data_p,
    mincov=0.5,
)
# Out:
# 16 previous results loaded for run [test_denovo_parent_k2-4]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 177550
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 178934
# Sites after filtering: 66387
# Sites containing missing values: 66317 (99.89%)
# Missing values in SNP matrix: 455780 (40.39%)
# SNPs (total): 66387
# SNPs (unlinked): 19113

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
#more reps did not seem to make a difference, can I plot each rep separately?
# Out:
# [K2] 10/10 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2 with less missing data?
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov9",
    data=data_p,
    mincov=0.9,
)

struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

#denovo parent assembly k=2-5, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 245111
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 245145
# Sites after filtering: 176
# Sites containing missing values: 106 (60.23%)
# Missing values in SNP matrix: 106 (3.54%)
# SNPs (total): 176
# SNPs (unlinked): 66
# [####################] 100% 0:00:21 | running 3 structure jobs

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2 with less missing data?
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov8",
    data=data_p,
    mincov=0.8,
)

struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

#denovo parent assembly k=2-5, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 244089
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 244141
# Sites after filtering: 1180
# Sites containing missing values: 1110 (94.07%)
# Missing values in SNP matrix: 2940 (14.66%)
# SNPs (total): 1180
# SNPs (unlinked): 315
# [####################] 100% 0:01:04 | running 3 structure jobs

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2, mincov 80, more burnin/reps
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov8_2",
    data=data_p,
    mincov=0.8,
)

struct.mainparams.burnin = 10000
struct.mainparams.numreps = 50000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
#pretty different from lower burnin/reps -> keep upping number and test
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 244089
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 244141
# Sites after filtering: 1180
# Sites containing missing values: 1110 (94.07%)
# Missing values in SNP matrix: 2940 (14.66%)
# SNPs (total): 1180
# SNPs (unlinked): 315
# [####################] 100% 0:04:08 | running 3 structure jobs

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2, mincov 80, more burnin/reps
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov8_3",
    data=data_p,
    mincov=0.8,
)

struct.mainparams.burnin = 100000
struct.mainparams.numreps = 500000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
#similar results to last run, but still not distinguishing well between samples
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 244089
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 244141
# Sites after filtering: 1180
# Sites containing missing values: 1110 (94.07%)
# Missing values in SNP matrix: 2940 (14.66%)
# SNPs (total): 1180
# SNPs (unlinked): 315
# [####################] 100% 0:36:34 | running 3 structure jobs

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2 parents with more snps/lower mincov
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov_1",
    data=data_p,
    mincov=0.3,
)


struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
#51879 snps at mincov 0.3, 19000 snps at mincov 0.5, 315 snps at mincov 0.8
#started at 8:40 burnin 2500, numreps 250000, didn't run in 10 hours
#try again with 5000burnin/10000reps just to test started at 8:35 -> took about and hour
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [####################] 100% 0:56:36 | running 3 structure jobs

# %%
#load above structure object
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov_1",
    data=data_p,
    mincov=0.3,
)
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# 3 previous results loaded for run [test_denovo_parent_k2_mincov_1]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2 parents with more snps/lower mincov
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov3_2",
    data=data_p,
    mincov=0.3,
)


struct.mainparams.burnin = 10000
struct.mainparams.numreps = 50000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
#51879 snps at mincov 0.3, 19000 snps at mincov 0.5, 315 snps at mincov 0.8
#started at 8:40 burnin 2500, numreps 250000, didn't run in 10 hours
#try again with 10000burnin/50000reps started at 12:50 -> ran out of time at 8:30, try fewer total reps
#with 3 total reps, 10000burnin/50000reps took about 4 hours
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [                    ]   0% 1:26:08 | running 3 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [######              ]  33% 3:45:30 | running 3 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# ...

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#what happens for k=2 parents, mincov 3, more burnin/reps
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov3_3",
    data=data_p,
    mincov=0.3,
)


struct.mainparams.burnin = 20000
struct.mainparams.numreps = 100000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [                    ]   0% 2:38:06 | running 3 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [                    ]   0% 6:06:47 | running 3 structure jobs

# %%
#started this next run with 12 hours, 8 cores @ 5gb each
#reload results from last cell 
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov3_3",
    data=data_p,
    mincov=0.3,
)
# Out:
# 3 previous results loaded for run [test_denovo_parent_k2_mincov3_3]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#increase burnin/reps, up it again

#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov3_4",
    data=data_p,
    mincov=0.3,
)

struct.mainparams.burnin = 50000
struct.mainparams.numreps = 250000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [                    ]   0% 0:53:51 | running 6 structure jobs

# %%
#above job ran, finishing around 4am (3:20-3:50)
#initiate structure object for denovo parents
struct = ipa.structure(
    name="test_denovo_parent_k2_mincov3_4",
    data=data_p,
    mincov=0.3,
)
# Out:
# 3 previous results loaded for run [test_denovo_parent_k2_mincov3_4]
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879

# %%
#parents: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#above k=2 looked pretty close to good, move on to k=3,4 test now

#initiate structure object for denovo parents
struct = ipa.structure(
    name="denovo_parent_k34_mincov3_1",
    data=data_p,
    mincov=0.3,
)

#start small for test
struct.mainparams.burnin = 50
struct.mainparams.numreps = 200

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[3,4], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [####################] 100% 0:03:16 | running 6 structure jobs

# %%
#parents: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=4
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 4
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6", "#67a9cf"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K4] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#initiate structure object for denovo parents
struct = ipa.structure(
    name="denovo_parent_k34_mincov3_2",
    data=data_p,
    mincov=0.3,
)

#start small for test
struct.mainparams.burnin = 2000
struct.mainparams.numreps = 13000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[3,4], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [####################] 100% 1:43:52 | running 6 structure jobs

# %%
#parents: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=4
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 4
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6", "#67a9cf"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K4] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#20,000 burnin and 100,000 reps matches a previous K2 run for these samples with this mincov3
#next try k=2,3 with more reps over 24 hours

#initiate structure object for denovo parents
struct = ipa.structure(
    name="denovo_parent_k34_mincov3_3",
    data=data_p,
    mincov=0.3,
)

#matches a previous k=2 run
struct.mainparams.burnin = 20000
struct.mainparams.numreps = 100000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[3,4], auto=True)
# Out:
# Samples: 17
# Sites before filtering: 245292
# Filtered (indels): 3729
# Filtered (bi-allel): 3224
# Filtered (mincov): 66047
# Filtered (minmap): 0
# Filtered (subsample invariant): 183
# Filtered (minor allele frequency): 0
# Filtered (combined): 70145
# Sites after filtering: 175176
# Sites containing missing values: 175106 (99.96%)
# Missing values in SNP matrix: 1546817 (51.94%)
# SNPs (total): 175176
# SNPs (unlinked): 51879
# [                    ]   0% 0:52:50 | running 6 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [                    ]   0% 3:55:19 | running 6 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# ...

# %%
#parents: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2,0])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#parents: k=4
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 4
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[0,2])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6", "#67a9cf"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "30px"}
# Out:
# [K4] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#initiate structure object for denovo hybrids, small test job
struct = ipa.structure(
    name="denovo_hybrid_k23_mincov3_1",
    data=data_h,
    mincov=0.3,
)

struct.mainparams.burnin = 20
struct.mainparams.numreps = 50

#downstream analysis combines reps
struct.run(nreps=3, kpop=[2,3], auto=True)
# Out:
# Samples: 119
# Sites before filtering: 723904
# Filtered (indels): 68993
# Filtered (bi-allel): 23681
# Filtered (mincov): 356145
# Filtered (minmap): 0
# Filtered (subsample invariant): 328
# Filtered (minor allele frequency): 0
# Filtered (combined): 375739
# Sites after filtering: 348299
# Sites containing missing values: 348222 (99.98%)
# Missing values in SNP matrix: 21149622 (51.03%)
# SNPs (total): 348299
# SNPs (unlinked): 76353
# [####################] 100% 0:08:16 | running 6 structure jobs

# %%
#hybrids: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#hybrids: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2,0])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#denovo hybrids increase burnin/reps
struct = ipa.structure(
    name="denovo_hybrid_k23_mincov3_2",
    data=data_h,
    mincov=0.3,
)

struct.mainparams.burnin = 200
struct.mainparams.numreps = 1000

#downstream analysis combines reps
struct.run(nreps=3, kpop=[2,3], auto=True)
# Out:
# Samples: 119
# Sites before filtering: 723904
# Filtered (indels): 68993
# Filtered (bi-allel): 23681
# Filtered (mincov): 356145
# Filtered (minmap): 0
# Filtered (subsample invariant): 328
# Filtered (minor allele frequency): 0
# Filtered (combined): 375739
# Sites after filtering: 348299
# Sites containing missing values: 348222 (99.98%)
# Missing values in SNP matrix: 21149622 (51.03%)
# SNPs (total): 348299
# SNPs (unlinked): 76353
# [####################] 100% 0:30:24 | running 6 structure jobs

# %%
#hybrids: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#hybrids: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2,0])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a", "#d0d1e6"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#denovo hybrids increase burnin/reps
struct = ipa.structure(
    name="denovo_hybrid_k23_mincov3_3",
    data=data_h,
    mincov=0.3,
)

struct.mainparams.burnin = 1000
struct.mainparams.numreps = 5000

#denovo parent assembly k=2, 3 reps 
#downstream analysis combines reps
struct.run(nreps=3, kpop=[2,3], auto=True)
# Out:
# Samples: 119
# Sites before filtering: 723904
# Filtered (indels): 68993
# Filtered (bi-allel): 23681
# Filtered (mincov): 356145
# Filtered (minmap): 0
# Filtered (subsample invariant): 328
# Filtered (minor allele frequency): 0
# Filtered (combined): 375739
# Sites after filtering: 348299
# Sites containing missing values: 348222 (99.98%)
# Missing values in SNP matrix: 21149622 (51.03%)
# SNPs (total): 348299
# SNPs (unlinked): 76353
# [####################] 100% 2:06:22 | running 6 structure jobs

# %%
#hybrids: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#hybrids: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2,0])

#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#d0d1e6", "#BC8F8F", "#02818a"]

# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "20px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#run hybrids for longer at mincov3
#initiate structure object for denovo parents
struct = ipa.structure(
    name="denovo_hybrid_k23_mincov3_4",
    data=data_h,
    mincov=0.3,)

struct.mainparams.burnin = 20000
struct.mainparams.numreps = 40000
struct.run(nreps=3, kpop=[2,3], auto=True)
# Out:
# Samples: 119
# Sites before filtering: 723904
# Filtered (indels): 68993
# Filtered (bi-allel): 23681
# Filtered (mincov): 356145
# Filtered (minmap): 0
# Filtered (subsample invariant): 328
# Filtered (minor allele frequency): 0
# Filtered (combined): 375739
# Sites after filtering: 348299
# Sites containing missing values: 348222 (99.98%)
# Missing values in SNP matrix: 21149622 (51.03%)
# SNPs (total): 348299
# SNPs (unlinked): 76353
# [                    ]   0% 3:14:44 | running 6 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [                    ]   0% 5:49:40 | running 6 structure jobs
# IOPub message rate exceeded.
# ...

# %%
#hybrids: k=2
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1])
#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#02818a","#BC8F8F"]
# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)
# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "18px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#hybrids: k=3
#lautum on right/mauve/#BC8F8F, jucundum on left/teal/#02818a
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[1,2])
#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#d0d1e6","#02818a","#BC8F8F"]
# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)
# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "18px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#run hybrids for longer at mincov3
#initiate structure object 
struct = ipa.structure(
    name="denovo_hybrid_k23_mincov3_5",
    data=data_h,
    mincov=0.3,)

struct.mainparams.burnin = 50000
struct.mainparams.numreps = 100000
struct.run(nreps=3, kpop=[2,3], auto=True)
# Out:
# Samples: 119
# Sites before filtering: 723904
# Filtered (indels): 68993
# Filtered (bi-allel): 23681
# Filtered (mincov): 356145
# Filtered (minmap): 0
# Filtered (subsample invariant): 328
# Filtered (minor allele frequency): 0
# Filtered (combined): 375739
# Sites after filtering: 348299
# Sites containing missing values: 348222 (99.98%)
# Missing values in SNP matrix: 21149622 (51.03%)
# SNPs (total): 348299
# SNPs (unlinked): 76353
# [                    ]   0% 2:48:10 | running 6 structure jobs
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [                    ]   0% 5:23:04 | running 6 structure jobs
# IOPub message rate exceeded.
# ...

# %%
#hybrids: k=2
#lautum on left/mauve/#BC8F8F, jucundum on right/teal/#02818a
k = 2
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[0])
#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#02818a","#BC8F8F"]
# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)
# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "18px"}
# Out:
# [K2] 3/3 results permuted across replicates (max_var=0).
# ...

# %%
#hybrids: k=3
#lautum on left/mauve/#BC8F8F, jucundum on right/teal/#02818a, light purple are yashtinin snps
k = 3
table = struct.get_clumpp_table(k)
table = table.sort_values(by=[2,0])
#colors = ["#02818a", "#d0d1e6", "#BC8F8F", "#67a9cf", "#014636"]
colors = ["#d0d1e6","#BC8F8F","#02818a"]
# build barplot
canvas = toyplot.Canvas(width=3000, height=1000)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table, color=colors)
# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "18px"}
# Out:
# [K3] 3/3 results permuted across replicates (max_var=0).
# ...
